# %% [markdown]
# <a href="https://colab.research.google.com/github/jayvazil/python/blob/main/pandasdtsetcsv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
pd.read_csv('/content/survey_results_public.csv', engine='python', on_bad_lines='skip')
df = pd.read_csv('/content/survey_results_public.csv', engine='python', on_bad_lines='skip')

# %%
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1                     I am a developer by profession      Yes
# 1               2                     I am a developer by profession       No
# 2               3                        I code primarily as a hobby      Yes
# 3               4                     I am a developer by profession      Yes
# 4               5  I used to be a developer by profession, but no...      Yes
# ...           ...                                                ...      ...
# 64456       64858                                                NaN      Yes
# 64457       64867                                                NaN      Yes
# 64458       64898                                                NaN      Yes
# 64459       64925                                                NaN      Yes
# 64460       65112                                                NaN      Yes
#
# ...

# %%
print(df)
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1                     I am a developer by profession      Yes
# 1               2                     I am a developer by profession       No
# 2               3                        I code primarily as a hobby      Yes
# 3               4                     I am a developer by profession      Yes
# 4               5  I used to be a developer by profession, but no...      Yes
# ...           ...                                                ...      ...
# 64456       64858                                                NaN      Yes
# 64457       64867                                                NaN      Yes
# 64458       64898                                                NaN      Yes
# 64459       64925                                                NaN      Yes
# 64460       65112                                                NaN      Yes
#
# ...

# %%
df.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1                     I am a developer by profession      Yes
# 1           2                     I am a developer by profession       No
# 2           3                        I code primarily as a hobby      Yes
# 3           4                     I am a developer by profession      Yes
# 4           5  I used to be a developer by profession, but no...      Yes
#
#     Age Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# 0   NaN         13  Monthly        NaN            NaN             Germany
# 1   NaN         19      NaN        NaN            NaN      United Kingdom
# 2   NaN         15      NaN        NaN            NaN  Russian Federation
# 3  25.0         18      NaN        NaN            NaN             Albania
# 4  31.0         16      NaN        NaN            NaN       United States
#
# ...

# %%
df.head(10)
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1                     I am a developer by profession      Yes
# 1           2                     I am a developer by profession       No
# 2           3                        I code primarily as a hobby      Yes
# 3           4                     I am a developer by profession      Yes
# 4           5  I used to be a developer by profession, but no...      Yes
# 5           6                     I am a developer by profession       No
# 6           7                     I am a developer by profession      Yes
# 7           8                     I am a developer by profession      Yes
# 8           9                     I am a developer by profession       No
# 9          10                     I am a developer by profession      Yes
#
#     Age Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# 0   NaN         13  Monthly        NaN            NaN             Germany
# ...

# %%
df.tail()
# Out:
#        Respondent MainBranch Hobbyist  Age Age1stCode CompFreq  CompTotal  \
# 64456       64858        NaN      Yes  NaN         16      NaN        NaN
# 64457       64867        NaN      Yes  NaN        NaN      NaN        NaN
# 64458       64898        NaN      Yes  NaN        NaN      NaN        NaN
# 64459       64925        NaN      Yes  NaN        NaN      NaN        NaN
# 64460       65112        NaN      Yes  NaN        NaN      NaN        NaN
#
#        ConvertedComp        Country CurrencyDesc  ... SurveyEase SurveyLength  \
# 64456            NaN  United States          NaN  ...        NaN          NaN
# 64457            NaN        Morocco          NaN  ...        NaN          NaN
# 64458            NaN       Viet Nam          NaN  ...        NaN          NaN
# 64459            NaN         Poland          NaN  ...        NaN          NaN
# 64460            NaN          Spain          NaN  ...        NaN          NaN
#
# ...

# %%
df.tail(3)
# Out:
#        Respondent MainBranch Hobbyist  Age Age1stCode CompFreq  CompTotal  \
# 64458       64898        NaN      Yes  NaN        NaN      NaN        NaN
# 64459       64925        NaN      Yes  NaN        NaN      NaN        NaN
# 64460       65112        NaN      Yes  NaN        NaN      NaN        NaN
#
#        ConvertedComp   Country CurrencyDesc  ... SurveyEase SurveyLength  \
# 64458            NaN  Viet Nam          NaN  ...        NaN          NaN
# 64459            NaN    Poland          NaN  ...        NaN          NaN
# 64460            NaN     Spain          NaN  ...        NaN          NaN
#
#       Trans                                     UndergradMajor  \
# 64458   NaN                                                NaN
# 64459   NaN                                                NaN
# 64460   NaN  Computer science, computer engineering, or sof...
#
#             WebframeDesireNextYear                      WebframeWorkedWith  \
# ...

# %%
df.shape
# Out:
# (64461, 61)

# %%
df_length = len(df)
print(df_length)
# Out:
# 64461

# %%
df.describe()
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/core/nanops.py:1016: RuntimeWarning: overflow encountered in square
#   sqr = _ensure_numeric((avg - values) ** 2)
#          Respondent           Age      CompTotal  ConvertedComp   WorkWeekHrs
# count  64461.000000  45446.000000   3.482600e+04   3.475600e+04  41151.000000
# mean   32554.079738     30.834111  3.190464e+242   1.037561e+05     40.782174
# std    18967.442360      9.585392            inf   2.268853e+05     17.816383
# min        1.000000      1.000000   0.000000e+00   0.000000e+00      1.000000
# 25%    16116.000000     24.000000   2.000000e+04   2.464800e+04     40.000000
# 50%    32231.000000     29.000000   6.300000e+04   5.404900e+04     40.000000
# 75%    49142.000000     35.000000   1.250000e+05   9.500000e+04     44.000000
# max    65639.000000    279.000000  1.111111e+247   2.000000e+06    475.000000

# %%
df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'Age', 'Age1stCode', 'CompFreq',
#        'CompTotal', 'ConvertedComp', 'Country', 'CurrencyDesc',
#        'CurrencySymbol', 'DatabaseDesireNextYear', 'DatabaseWorkedWith',
#        'DevType', 'EdLevel', 'Employment', 'Ethnicity', 'Gender', 'JobFactors',
#        'JobSat', 'JobSeek', 'LanguageDesireNextYear', 'LanguageWorkedWith',
#        'MiscTechDesireNextYear', 'MiscTechWorkedWith',
#        'NEWCollabToolsDesireNextYear', 'NEWCollabToolsWorkedWith', 'NEWDevOps',
#        'NEWDevOpsImpt', 'NEWEdImpt', 'NEWJobHunt', 'NEWJobHuntResearch',
#        'NEWLearn', 'NEWOffTopic', 'NEWOnboardGood', 'NEWOtherComms',
#        'NEWOvertime', 'NEWPurchaseResearch', 'NEWPurpleLink', 'NEWSOSites',
#        'NEWStuck', 'OpSys', 'OrgSize', 'PlatformDesireNextYear',
#        'PlatformWorkedWith', 'PurchaseWhat', 'Sexuality', 'SOAccount',
#        'SOComm', 'SOPartFreq', 'SOVisitFreq', 'SurveyEase', 'SurveyLength',
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64461 entries, 0 to 64460
# Data columns (total 61 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Respondent                    64461 non-null  int64
#  1   MainBranch                    64162 non-null  object
#  2   Hobbyist                      64416 non-null  object
#  3   Age                           45446 non-null  float64
#  4   Age1stCode                    57900 non-null  object
#  5   CompFreq                      40069 non-null  object
#  6   CompTotal                     34826 non-null  float64
#  7   ConvertedComp                 34756 non-null  float64
#  8   Country                       64072 non-null  object
#  9   CurrencyDesc                  45472 non-null  object
#  10  CurrencySymbol                45472 non-null  object
#  11  DatabaseDesireNextYear        44070 non-null  object
# ...

# %%
df.dtypes
# Out:
# Respondent              int64
# MainBranch             object
# Hobbyist               object
# Age                   float64
# Age1stCode             object
#                        ...
# WebframeWorkedWith     object
# WelcomeChange          object
# WorkWeekHrs           float64
# YearsCode              object
# YearsCodePro           object
# Length: 61, dtype: object

# %%
df.dtypes.unique()
# Out:
# array([dtype('int64'), dtype('O'), dtype('float64')], dtype=object)

# %%
df.dtypes.value_counts()
# Out:
# object     56
# float64     4
# int64       1
# Name: count, dtype: int64

# %%
df['Hobbyist'].unique()
# print(df.iloc([10]))
# Out:
# array(['Yes', 'No', nan], dtype=object)

# %%
#dictionary

courses = {
    "Name":"Ephy",
    "Age":19,
    "Course":"Data Science",
    "Year":2023
}

name = courses["Name"]
print(name)
# Out:
# Ephy

# %%
courses.keys()
# Out:
# dict_keys(['Name', 'Age', 'Course', 'Year'])

# %%
age = [12,23,32,64,47]
print(age[0])
# Out:
# 12

# %%
df['Hobbyist'].value_counts()
# Out:
# Hobbyist
# Yes    50388
# No     14028
# Name: count, dtype: int64

# %%
df['Age'].value_counts()
df.iloc([0][0])

# %%
# prompt: use iloc in this dataset

# Access the element at row 0 and column 0
# print(df.iloc[0, 0])

# Access the first 5 rows and the first 3 columns
print(df.iloc[4, 10])

# Access rows 10 to 15 and columns 2 to 5
# print(df.iloc[10:16, 2:6])

# Access specific rows and columns using lists
# print(df.iloc[[0, 3, 5], [1, 3, 5]])
# Out:
# nan

# %%
df.head(0)
# Out:
# Empty DataFrame
# Columns: [Respondent, MainBranch, Hobbyist, Age, Age1stCode, CompFreq, CompTotal, ConvertedComp, Country, CurrencyDesc, CurrencySymbol, DatabaseDesireNextYear, DatabaseWorkedWith, DevType, EdLevel, Employment, Ethnicity, Gender, JobFactors, JobSat, JobSeek, LanguageDesireNextYear, LanguageWorkedWith, MiscTechDesireNextYear, MiscTechWorkedWith, NEWCollabToolsDesireNextYear, NEWCollabToolsWorkedWith, NEWDevOps, NEWDevOpsImpt, NEWEdImpt, NEWJobHunt, NEWJobHuntResearch, NEWLearn, NEWOffTopic, NEWOnboardGood, NEWOtherComms, NEWOvertime, NEWPurchaseResearch, NEWPurpleLink, NEWSOSites, NEWStuck, OpSys, OrgSize, PlatformDesireNextYear, PlatformWorkedWith, PurchaseWhat, Sexuality, SOAccount, SOComm, SOPartFreq, SOVisitFreq, SurveyEase, SurveyLength, Trans, UndergradMajor, WebframeDesireNextYear, WebframeWorkedWith, WelcomeChange, WorkWeekHrs, YearsCode, YearsCodePro]
# Index: []
#
# [0 rows x 61 columns]

# %%
df.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1                     I am a developer by profession      Yes
# 1           2                     I am a developer by profession       No
# 2           3                        I code primarily as a hobby      Yes
# 3           4                     I am a developer by profession      Yes
# 4           5  I used to be a developer by profession, but no...      Yes
#
#     Age Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# 0   NaN         13  Monthly        NaN            NaN             Germany
# 1   NaN         19      NaN        NaN            NaN      United Kingdom
# 2   NaN         15      NaN        NaN            NaN  Russian Federation
# 3  25.0         18      NaN        NaN            NaN             Albania
# 4  31.0         16      NaN        NaN            NaN       United States
#
# ...

# %%
data = {
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [25, 30, None],
    'City': ['New York', 'San Francisco', 'Los Angeles']
}

# Create a DataFrame from the dictionary

df = pd.DataFrame(data)
df
# Out:
#       Name   Age           City
# 0    Alice  25.0       New York
# 1      Bob  30.0  San Francisco
# 2  Charlie   NaN    Los Angeles

# %%
df.dropna(inplace=True)
df
# Out:
#     Name   Age           City
# 0  Alice  25.0       New York
# 1    Bob  30.0  San Francisco

# %%
df.fillna(30)
# Out:
#     Name   Age           City
# 0  Alice  25.0       New York
# 1    Bob  30.0  San Francisco

# %%
#drop a column
df.drop(columns=['Age'])
df
# Out:
#     Name   Age           City
# 0  Alice  25.0       New York
# 1    Bob  30.0  San Francisco

# %%
# prompt: use groupby

# Group by 'Hobbyist' and count the number of respondents in each group
name_counts = df.groupby('Name').count()
print(name_counts)
# Out:
#        Age  City
# Name
# Alice    1     1
# Bob      1     1

# %%
# age_mean = df.groupby('Age').mean()
# print(name_counts)
df['Age']
# Out:
# 0    25.0
# 1    30.0
# Name: Age, dtype: float64

# %%
# age_mean = df.groupby('Age').mean()
# print(name_counts)
df['Age'].astype(int)
# Out:
# 0    25
# 1    30
# Name: Age, dtype: int64

# %%
age_mean = df.groupby('Age').count()
print(name_counts)
# Out:
#        Age  City
# Name
# Alice    1     1
# Bob      1     1

# %%
# Convert 'Age' column to numeric, handling errors
df['Age'] = pd.to_numeric(df['Age'], errors='coerce')

# Group by 'Age' and calculate the mean of numeric columns only
age_mean = df.groupby('Age').mean(numeric_only=True)
print(age_mean)
# Out:
# Empty DataFrame
# Columns: []
# Index: [25, 30]

# %%
df.dtypes
# Out:
# Name     object
# Age     float64
# City     object
# dtype: object

# %%
df['Age']=df['Age'].astype(int)
df.dtypes
# Out:
# Name    object
# Age      int64
# City    object
# dtype: object

# %%
# prompt: cnvert the dataframe to a csv

# Assuming 'df' is your DataFrame
df.to_csv('class.csv', index=False)  # Save to a CSV file named 'survey_results.csv'
# index=False prevents the DataFrame index from being written to the CSV.

# %%
df = pd.read_csv('/content/class.csv')

# %%
df
# Out:
#     Name  Age           City
# 0  Alice   25       New York
# 1    Bob   30  San Francisco
