# %% [markdown]
# <a href="https://colab.research.google.com/github/jayvazil/python/blob/main/datasetBk2jay.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
# prompt: import a csv file

df = pd.read_csv('/content/Bk2jay.csv', engine='python', on_bad_lines='skip')
df
# Out:
#               CUSTOMER     PRODUCTS     SALES PERSON    REGION  ORDER DATE  \
# 0     LONG ISLANDS INC  SOFT DRINKS  Michael Jackson  AMERICAS   4/13/2012
# 1     LONG ISLANDS INC  SOFT DRINKS  Michael Jackson  AMERICAS  12/21/2012
# 2     LONG ISLANDS INC  SOFT DRINKS  Michael Jackson  AMERICAS  12/24/2012
# 3     LONG ISLANDS INC  SOFT DRINKS  Michael Jackson  AMERICAS  12/24/2012
# 4     LONG ISLANDS INC  SOFT DRINKS  Michael Jackson  AMERICAS  12/29/2012
# ..                 ...          ...              ...       ...         ...
# 572  GIN ON THE RUN CO        TONIC    Homer Simpson    AFRICA  12/17/2014
# 573  GIN ON THE RUN CO        TONIC    Homer Simpson    AFRICA    1/5/2014
# 574  GIN ON THE RUN CO        TONIC    Homer Simpson    AFRICA    1/5/2014
# 575  GIN ON THE RUN CO        TONIC    Homer Simpson    AFRICA    1/5/2014
# 576  GIN ON THE RUN CO        TONIC    Homer Simpson    AFRICA    1/6/2014
#
#     SALES USD  YEAR      MONTH QTR       CHANNEL PARTNERS
# ...

# %%
print(df)
# Out:
#               CUSTOMER     PRODUCTS     SALES PERSON    REGION  ORDER DATE  \
# 0     LONG ISLANDS INC  SOFT DRINKS  Michael Jackson  AMERICAS   4/13/2012
# 1     LONG ISLANDS INC  SOFT DRINKS  Michael Jackson  AMERICAS  12/21/2012
# 2     LONG ISLANDS INC  SOFT DRINKS  Michael Jackson  AMERICAS  12/24/2012
# 3     LONG ISLANDS INC  SOFT DRINKS  Michael Jackson  AMERICAS  12/24/2012
# 4     LONG ISLANDS INC  SOFT DRINKS  Michael Jackson  AMERICAS  12/29/2012
# ..                 ...          ...              ...       ...         ...
# 572  GIN ON THE RUN CO        TONIC    Homer Simpson    AFRICA  12/17/2014
# 573  GIN ON THE RUN CO        TONIC    Homer Simpson    AFRICA    1/5/2014
# 574  GIN ON THE RUN CO        TONIC    Homer Simpson    AFRICA    1/5/2014
# 575  GIN ON THE RUN CO        TONIC    Homer Simpson    AFRICA    1/5/2014
# 576  GIN ON THE RUN CO        TONIC    Homer Simpson    AFRICA    1/6/2014
#
#     SALES USD  YEAR      MONTH QTR       CHANNEL PARTNERS
# ...

# %%
df.head()
# Out:
#            CUSTOMER     PRODUCTS     SALES PERSON    REGION  ORDER DATE  \
# 0  LONG ISLANDS INC  SOFT DRINKS  Michael Jackson  AMERICAS   4/13/2012
# 1  LONG ISLANDS INC  SOFT DRINKS  Michael Jackson  AMERICAS  12/21/2012
# 2  LONG ISLANDS INC  SOFT DRINKS  Michael Jackson  AMERICAS  12/24/2012
# 3  LONG ISLANDS INC  SOFT DRINKS  Michael Jackson  AMERICAS  12/24/2012
# 4  LONG ISLANDS INC  SOFT DRINKS  Michael Jackson  AMERICAS  12/29/2012
#
#   SALES USD  YEAR     MONTH QTR CHANNEL PARTNERS
# 0   25,000   2012   January  Q1       Acme, inc.
# 1   24,640   2012  February  Q1      Widget Corp
# 2   29,923   2012     March  Q1  123 Warehousing
# 3   66,901   2012     April  Q2     Demo Company
# 4   63,116   2012       May  Q2    Smith and Co.

# %%
df.tail()
# Out:
#               CUSTOMER PRODUCTS   SALES PERSON  REGION  ORDER DATE SALES USD  \
# 572  GIN ON THE RUN CO    TONIC  Homer Simpson  AFRICA  12/17/2014   60,244
# 573  GIN ON THE RUN CO    TONIC  Homer Simpson  AFRICA    1/5/2014   76,362
# 574  GIN ON THE RUN CO    TONIC  Homer Simpson  AFRICA    1/5/2014   60,119
# 575  GIN ON THE RUN CO    TONIC  Homer Simpson  AFRICA    1/5/2014   45,139
# 576  GIN ON THE RUN CO    TONIC  Homer Simpson  AFRICA    1/6/2014    99,999
#
#      YEAR      MONTH QTR       CHANNEL PARTNERS
# 572  2014  September  Q3          St. Anky Beer
# 573  2014    October  Q4  Stay Puft Corporation
# 574  2014   November  Q4    Vandelay Industries
# 575  2014   December  Q4           Wernham Hogg
# 576  2014   December  Q4                Initech

# %%
df.shape
# Out:
# (577, 10)

# %%
df_length = len(df)
print(df_length)
# Out:
# 577

# %%
df.describe()
# Out:
#               YEAR
# count   577.000000
# mean   2013.001733
# std       0.817557
# min    2012.000000
# 25%    2012.000000
# 50%    2013.000000
# 75%    2014.000000
# max    2014.000000

# %%
df.columns
# Out:
# Index(['CUSTOMER', 'PRODUCTS', 'SALES PERSON', 'REGION', 'ORDER DATE',
#        'SALES USD', 'YEAR', 'MONTH', 'QTR', 'CHANNEL PARTNERS'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 577 entries, 0 to 576
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   CUSTOMER          577 non-null    object
#  1   PRODUCTS          577 non-null    object
#  2   SALES PERSON      577 non-null    object
#  3   REGION            577 non-null    object
#  4   ORDER DATE        577 non-null    object
#  5   SALES USD         577 non-null    object
#  6   YEAR              577 non-null    int64
#  7   MONTH             577 non-null    object
#  8   QTR               577 non-null    object
#  9   CHANNEL PARTNERS  577 non-null    object
# dtypes: int64(1), object(9)
# memory usage: 45.2+ KB

# %%
df.dtypes
# Out:
# CUSTOMER            object
# PRODUCTS            object
# SALES PERSON        object
# REGION              object
# ORDER DATE          object
# SALES USD           object
# YEAR                 int64
# MONTH               object
# QTR                 object
# CHANNEL PARTNERS    object
# dtype: object

# %%
df.dtypes.unique()
# Out:
# array([dtype('O'), dtype('int64')], dtype=object)

# %%
df.dtypes.value_counts()
# Out:
# object    9
# int64     1
# Name: count, dtype: int64
